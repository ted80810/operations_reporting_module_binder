# %% [markdown]
# # Operations Reporting Module

# %% [markdown]
# The code is stored in a container called jupyter-lite. This container contains all the libraries and programs needed to run the code. Jupyter-lite is a web based container so you simply need the link to open the application. However, the code is stored in a cloud space so local file can only be accessed through an extension. The extension is already installed, but it only works in Google Chrome currently.
#
# To run the code, upload the pdf to the same folder as the file label pdf_conveter.ipynb. This is the raw code so you will to specify the filename and number of pages right in the code. You need to specify the name of the file where it says “type filename”. Specify the number of pages in the document where it says, “type number of pages here.” Lastly, to run the code click the first cell at the top of the page under the title then press shift+enter to run that cell. Always start from the first code cell moving downward.

# %%
# Import the required Module
import tabula
import pandas as pd
import numpy as np
import os
import warnings
warnings.filterwarnings("ignore")

# %%
os.getcwd()
# Out:
# '/Users/TheodoreThompson/Documents/Bahamas_Geospatial_Services/operations_reporting_module/content'

# %%
os.chdir('content')

# %% [markdown]
# ### Configuration

# %%
Restaurant = "MS"

# %%
# enter year of filename
year = "2022"

# %%
# enter month of filename
short_month = "Aug"

# %% [markdown]
# ### Hours Register

# %%
Report_Name = "Hours_Register"

# %%
# Read a PDF File
# hr = tabula.read_pdf(f'/{Report_Name}/{Report_Name}_{short_month}_{year}.pdf', stream=True, pages=3, guess=False, pandas_options={'header': None},
#                      columns=(52.47, 165.55,235.55,292.63,346.88,390.42,430.31,472.13,523.42,575.88,622.33,661.71,712.50))[0]
# hr
hr = pd.read_csv(f'{Report_Name}/{Report_Name}_{short_month}_{year}.csv', skiprows = 3) # skip first 3 rows
hr
# Out:
#                 Unnamed: 0  Unnamed: 1        Unnamed: 2  Unnamed: 3  \
# 0                 Store #1         NaN               NaN         NaN
# 1                     CREW         NaN               NaN         NaN
# 2        ADDERLEY, JERMAIN         NaN               NaN         NaN
# 3        ADDERLEY, JERMAIN         NaN               NaN         NaN
# 4        ADDERLEY, JERMAIN         NaN               NaN         NaN
# ..                     ...         ...               ...         ...
# 834                    NaN         NaN               NaN         NaN
# 835                    NaN         NaN               NaN         NaN
# 836                    NaN         NaN               NaN         7.0
# 837                    NaN         NaN  Total Employees          NaN
# 838                    NaN         NaN               NaN         NaN
#
#      Unnamed: 4 Unnamed: 5 Unnamed: 6  Unnamed: 7  Unnamed: 8   Regular  \
# ...

# %% [markdown]
# ### Break up rows with store information into seperate DataFrame

# %% [markdown]
# Store #1

# %%
start_rows = [4,135,172,179,189,204] #store 1
end_rows = [131,168,175,185,200,210]

start_rows = [number - 1 for number in start_rows] #python row index starts at 0 not 1, so must subtract 1 from each number
end_rows = [number - 1 for number in end_rows]

# %%
crew_01 = hr.iloc[start_rows[0]:end_rows[0]]
crew_01.iat[0,1] = 'crew'
crew_01.iat[0,2] = '01'
crew_01 = crew_01.ffill(axis = 0)

crew_trainer_01 = hr.iloc[start_rows[1]:end_rows[1]]
crew_trainer_01.iat[0,1] = 'crew trainer'
crew_trainer_01.iat[0,2] = '01'
crew_trainer_01 = crew_trainer_01.ffill(axis = 0)

maintenance_01 = hr.iloc[start_rows[2]:end_rows[2]]
maintenance_01.iat[0,1] = 'maintenance'
maintenance_01.iat[0,2] = '01'
maintenance_01.ffill(axis = 0)

star_01 = hr.iloc[start_rows[3]:end_rows[3]]
star_01.iat[0,1] = 'star'
star_01.iat[0,2] = '01'
star_01.ffill(axis = 0)

summer_student_01 = hr.iloc[start_rows[4]:end_rows[4]]
summer_student_01.iat[0,1] = 'summer student'
summer_student_01.iat[0,2] = '01'
summer_student_01.ffill(axis = 0)

trailer_01 = hr.iloc[start_rows[5]:end_rows[5]]
trailer_01.iat[0,1] = 'trailer'
trailer_01.iat[0,2] = '01'
trailer_01.ffill(axis = 0)

crew_01
crew_01.iat[0,1] = 'crew'
crew_01.iat[0,2] = '01'
crew_01 = crew_01.ffill(axis = 0)

# %% [markdown]
# Store #2

# %%
start_rows = [234,358,390,397,407] 
end_rows = [354,386,393,403,420]

start_rows = [number - 1 for number in start_rows] #python row index starts at 0 not 1, so must subtract 1 from each number
end_rows = [number - 1 for number in end_rows]

# %%
crew_02 = hr.iloc[start_rows[0]:end_rows[0]]
crew_02.iat[0,1] = 'crew'
crew_02.iat[0,2] = '02'
crew_02 = crew_02.ffill(axis = 0)

crew_trainer_02 = hr.iloc[start_rows[1]:end_rows[1]]
crew_trainer_02.iat[0,1] = 'crew trainer'
crew_trainer_02.iat[0,2] = '02'
crew_trainer_02 = crew_trainer_02.ffill(axis = 0)

maintenance_02 = hr.iloc[start_rows[2]:end_rows[2]]
maintenance_02.iat[0,1] = 'maintenance'
maintenance_02.iat[0,2] = '02'
maintenance_02 = maintenance_02.ffill(axis = 0)

summer_student_02 = hr.iloc[start_rows[3]:end_rows[3]]
summer_student_02.iat[0,1] = 'summer student'
summer_student_02.iat[0,2] = '02'
summer_student_02 = summer_student_02.ffill(axis = 0)

trailer_02 = hr.iloc[start_rows[4]:end_rows[4]]
trailer_02.iat[0,1] = 'trailer'
trailer_02.iat[0,2] = '02'
trailer_02 = trailer_02.ffill(axis = 0)

# %% [markdown]
# Store #3

# %%
start_rows = [434,573,592,599,610,627] 
end_rows = [569,588,595,606,623,631]

start_rows = [number - 1 for number in start_rows] #python row index starts at 0 not 1, so must subtract 1 from each number
end_rows = [number - 1 for number in end_rows]

# %%
crew_03 = hr.iloc[start_rows[0]:end_rows[0]]
crew_03.iat[0,1] = 'crew'
crew_03.iat[0,2] = '03'
crew_03 = crew_03.ffill(axis = 0)

crew_trainer_03 = hr.iloc[start_rows[1]:end_rows[1]]
crew_trainer_03.iat[0,1] = 'crew trainer'
crew_trainer_03.iat[0,2] = '03'
crew_trainer_03 = crew_trainer_03.ffill(axis = 0)

maintenance_03 = hr.iloc[start_rows[2]:end_rows[2]]
maintenance_03.iat[0,1] = 'maintenance'
maintenance_03.iat[0,2] = '03'
maintenance_03 = maintenance_03.ffill(axis = 0)

star_03 = hr.iloc[start_rows[3]:end_rows[3]]
star_03.iat[0,1] = 'star'
star_03.iat[0,2] = '03'
star_03 = star_03.ffill(axis = 0)

summer_student_03 = hr.iloc[start_rows[4]:end_rows[4]]
summer_student_03.iat[0,1] = 'summer student'
summer_student_03.iat[0,2] = '03'
summer_student_03 = summer_student_03.ffill(axis = 0)

trailer_03 = hr.iloc[start_rows[5]:end_rows[5]]
trailer_03.iat[0,1] = 'trailer'
trailer_03.iat[0,2] = '03'
trailer_03 = trailer_03.ffill(axis = 0)

# %% [markdown]
# Store #4

# %%
start_rows = [639,658,681,688] 
end_rows = [654,677,684,691]

start_rows = [number - 1 for number in start_rows] #python row index starts at 0 not 1, so must subtract 1 from each number
end_rows = [number - 1 for number in end_rows]

# %%
accounts_04 = hr.iloc[start_rows[0]:end_rows[0]]
accounts_04.iat[0,1] = 'accounts'
accounts_04.iat[0,2] = '04'
accounts_04 = accounts_04.ffill(axis = 0)

administrative_04 = hr.iloc[start_rows[1]:end_rows[1]]
administrative_04.iat[0,1] = 'trailer'
administrative_04.iat[0,2] = '04'
administrative_04 = administrative_04.ffill(axis = 0)

advertising_04 = hr.iloc[start_rows[2]:end_rows[2]]
advertising_04.iat[0,1] = 'advertising'
advertising_04.iat[0,2] = '04'
advertising_04 = advertising_04.ffill(axis = 0)

maintenance_04 = hr.iloc[start_rows[3]:end_rows[3]]
maintenance_04.iat[0,1] = 'maintenance'
maintenance_04.iat[0,2] = '04'
maintenance_04 = maintenance_04.ffill(axis = 0)

# %% [markdown]
# Store #5

# %%
start_rows = [699] 
end_rows = [706]

start_rows = [number - 1 for number in start_rows] #python row index starts at 0 not 1, so must subtract 1 from each number
end_rows = [number - 1 for number in end_rows]

# %%
A_A_Marlborough_05 = hr.iloc[start_rows[0]:end_rows[0]]

# %%
A_A_Marlborough_05.iat[0,1] = 'A_A_Marlborough'
A_A_Marlborough_05.iat[0,2] = '05'
A_A_Marlborough_05 = A_A_Marlborough_05.ffill(axis = 0)

# %% [markdown]
# Store #6

# %%
start_rows = [714] 
end_rows = [745]

start_rows = [number - 1 for number in start_rows] #python row index starts at 0 not 1, so must subtract 1 from each number
end_rows = [number - 1 for number in end_rows]

# %%
managers_06 = hr.iloc[start_rows[0]:end_rows[0]]

# %%
managers_06.iat[0,1] = 'managers'
managers_06.iat[0,2] = '06'
managers_06 = managers_06.ffill(axis = 0)

# %% [markdown]
# Store #7

# %%
start_rows = [753] 
end_rows = [781]

start_rows = [number - 1 for number in start_rows] #python row index starts at 0 not 1, so must subtract 1 from each number
end_rows = [number - 1 for number in end_rows]

# %%
managers_07 = hr.iloc[start_rows[0]:end_rows[0]]

# %%
managers_07.iat[0,1] = 'managers'
managers_07.iat[0,2] = '07'
managers_07 = managers_07.ffill(axis = 0)

# %% [markdown]
# Store #8

# %%
start_rows = [789] 
end_rows = [819]

start_rows = [number - 1 for number in start_rows] #python row index starts at 0 not 1, so must subtract 1 from each number
end_rows = [number - 1 for number in end_rows]

# %%
managers_08 = hr.iloc[start_rows[0]:end_rows[0]]

# %%
managers_08.iat[0,1] = 'managers'
managers_08.iat[0,2] = '08'
managers_08 = managers_08.ffill(axis = 0)

# %% [markdown]
# Store #9

# %%
start_rows = [827] 
end_rows = [833]

start_rows = [number - 1 for number in start_rows] #python row index starts at 0 not 1, so must subtract 1 from each number
end_rows = [number - 1 for number in end_rows]

# %%
managers_09 = hr.iloc[start_rows[0]:end_rows[0]]

# %%
managers_09.iat[0,1] = 'managers'
managers_09.iat[0,2] = '09'
managers_09 = managers_09.ffill(axis = 0)

# %% [markdown]
# Store #10

# %%
start_rows = [218] 
end_rows = [226]

start_rows = [number - 1 for number in start_rows] #python row index starts at 0 not 1, so must subtract 1 from each number
end_rows = [number - 1 for number in end_rows]

# %%
A_A_Madeira_10 = hr.iloc[start_rows[0]:end_rows[0]]

# %%
A_A_Madeira_10.iat[0,1] = 'managers'
A_A_Madeira_10.iat[0,2] = '10'
A_A_Madeira_10 = A_A_Madeira_10.ffill(axis = 0)

# %% [markdown]
# Concatenate all individual DataFrames

# %%
#concatenation
store_list = [crew_01,crew_trainer_01,maintenance_01,star_01,summer_student_01,trailer_01,
             crew_02,crew_trainer_02,maintenance_02,summer_student_02,trailer_02,crew_03,
              crew_trainer_03,maintenance_03,star_03,summer_student_03,trailer_03,accounts_04,
              administrative_04,advertising_04,maintenance_04,A_A_Marlborough_05,managers_06,
             managers_07,managers_08,managers_09,A_A_Madeira_10]  # List of your dataframes
df_result = pd.concat(store_list)
print('\n Concatenated Output  \n' ,df_result)
# Out:
#  Concatenated Output
#                     Unnamed: 0 Unnamed: 1 Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# 3           ADDERLEY, JERMAIN       crew         01         NaN         NaN
# 4           ADDERLEY, JERMAIN       crew         01         NaN         NaN
# 5           ADDERLEY, JERMAIN       crew         01         NaN         NaN
# 6               ALBURY, DAVID       crew         01         NaN         NaN
# 7               ALBURY, DAVID       crew         01         NaN         NaN
# ..                        ...        ...        ...         ...         ...
# 220      OSCAR - PIERRE, MARY   managers         10         NaN         NaN
# 221      OSCAR - PIERRE, MARY   managers         10         NaN         NaN
# 222      OSCAR - PIERRE, MARY   managers         10         NaN         NaN
# 223      OSCAR - PIERRE, MARY   managers         10         NaN         NaN
# 224        TAYLOR, DAVYANETTE   managers         10         NaN         NaN
#
# ...

# %% [markdown]
# Drop Empty Rows

# %%
df_result = df_result.drop(columns=['Unnamed: 3','Unnamed: 4','Unnamed: 5','Unnamed: 6','Unnamed: 18','Unnamed: 19'])

# %% [markdown]
# Name columns

# %%
df_result.columns = ['Employee Name', 'Employee Type', 'Store Number','Employee Number','NA','Regular','Other Reg','Time/Half','Double','Vac Allowance','Other','Sick','Other.1','Date']

# %%
hr_final = df_result
hr_final
# Out:
#                 Employee Name Employee Type Store Number  Employee Number  \
# 3           ADDERLEY, JERMAIN          crew           01         590311.0
# 4           ADDERLEY, JERMAIN          crew           01         590311.0
# 5           ADDERLEY, JERMAIN          crew           01         590311.0
# 6               ALBURY, DAVID          crew           01         590290.0
# 7               ALBURY, DAVID          crew           01         590290.0
# ..                        ...           ...          ...              ...
# 220      OSCAR - PIERRE, MARY      managers           10         102177.0
# 221      OSCAR - PIERRE, MARY      managers           10         102177.0
# 222      OSCAR - PIERRE, MARY      managers           10         102177.0
# 223      OSCAR - PIERRE, MARY      managers           10         102177.0
# 224        TAYLOR, DAVYANETTE      managers           10         691026.0
#
#       NA  Regular  Other Reg  Time/Half  Double  Vac Allowance  Other  Sick  \
# ...

# %% [markdown]
# Save file

# %%
hr_result.to_csv(f"Hours_Register/Hours_Register_{short_month}_{year}.csv")

# %% [markdown]
# ### Inventory Stat Report

# %%
Report_Name = "InventoryStat"

# %%
# Read a PDF File
isr = tabula.read_pdf(f'{Restaurant}/{Report_Name}/{Restaurant}_{Report_Name}_{short_month}_{year}.pdf', stream=True, pages=3, guess=False, pandas_options={'header': None},
                     columns=(52.47, 165.55,235.55,292.63,346.88,390.42,430.31,472.13,523.42,575.88,622.33,661.71,712.50))[0]
isr
# Out:
#             0                                           1           2   \
# 0          NaN                                 DANBRAD LTD         NaN
# 1          NaN                          rep_consumo_ant_va  lor_idl_en
# 2          NaN                           Ver: 201906051200         NaN
# 3          NaN                                         NaN         NaN
# 4   Wrin Numbe                               r Description         UOM
# 5    Company 2                     Description DANBRAD LTD         NaN
# 6        Store                     01 Description MARLBORU          GH
# 7        Class                        001 Description FOOD         NaN
# 8     Category                        001 Description FOOD         NaN
# 9         4887                       SPICY CHICKEN NUGGETS   UNIT-EACH
# 10         555                                  SUGAR BULK        BAGS
# 11          47                                SUGAR PACKET      PACKET
# ...

# %%
isr.columns = ['Wrin','Description','UOM','Initial Inv','Purchases','Trans+/-','Adjust','Account Adjust','Final Inv',
              'Actual Usage (Inventory)','Cond','Raw Waste','Theorical Usage P.mix)','Amount in $ Stat +/-']
isr
# Out:
#           Wrin                                 Description         UOM  \
# 0          NaN                                 DANBRAD LTD         NaN
# 1          NaN                          rep_consumo_ant_va  lor_idl_en
# 2          NaN                           Ver: 201906051200         NaN
# 3          NaN                                         NaN         NaN
# 4   Wrin Numbe                               r Description         UOM
# 5    Company 2                     Description DANBRAD LTD         NaN
# 6        Store                     01 Description MARLBORU          GH
# 7        Class                        001 Description FOOD         NaN
# 8     Category                        001 Description FOOD         NaN
# 9         4887                       SPICY CHICKEN NUGGETS   UNIT-EACH
# 10         555                                  SUGAR BULK        BAGS
# 11          47                                SUGAR PACKET      PACKET
# ...

# %%
isr = isr.drop(axis=0, labels=0)
isr = isr.drop(axis=0, labels=1)
isr = isr.drop(axis=0, labels=2)
isr = isr.drop(axis=0, labels=3)
isr = isr.drop(axis=0, labels=4)
isr = isr.drop(axis=0, labels=5)
isr = isr.drop(axis=0, labels=6)
isr = isr.drop(axis=0, labels=7)
isr = isr.drop(axis=0, labels=8)
isr
# Out:
#         Wrin                                 Description        UOM  \
# 9       4887                       SPICY CHICKEN NUGGETS  UNIT-EACH
# 10       555                                  SUGAR BULK       BAGS
# 11        47                                SUGAR PACKET     PACKET
# 12       168                                SYRUP SPRITE    GALLONS
# 13  15610000                          Spicy pepper sauce     POUNDS
# 14        57                                TEA BAGS HOT  UNIT-EACH
# 15       253                                    TOMATOES  UNIT-EACH
# 16      3470                            TOP - CRUSH M&MS      POUCH
# 17      3471                            TOP - CRUSH OREO       BAGS
# 18      7252                             TOP SUNDAE NUTS     PACKET
# 19        69                             TOPPING CARAMEL       BAGS
# 20        65                               TOPPING FUDGE       BAGS
# 21        67                          TOPPING STRAWBERRY       BAGS
# ...

# %% [markdown]
# ### Save to csv

# %%
isr.to_csv(f'{Restaurant}/{Report_Name}/{Restaurant}_{Report_Name}_{short_month}_{year}.pdf')

# %% [markdown]
# ### Daily Expense Report

# %%
#change report name
Report_Name = "DailyExpense"

# %%
der = tabula.read_pdf(f'{Restaurant}/{Report_Name}/{Restaurant}_{Report_Name}_{short_month}_{year}.pdf', stream=True, guess=False, pandas_options={'header': None},
                     columns=(80.52, 124.71,159.07,209.13,260.19,293.57,335.79,369.18,409.42,443.79,483.06,521.37,557.69))[0]
der
# Out:
# 'pages' argument isn't specified.Will extract only from page 1 by default.
#                  0            1         2            3             4   \
# 0   ===============  ===========  ========  ===========  ============
# 1   DANBRAD LIMITED          NaN       NaN          NaN           NaN
# 2   Store #52058 MA  RLBOROUGH S    TREET.  Information   from 08-01-
# 3               NaN          A/R     PETTY       CREDIT        KRAVEN
# 4              Date       MISCE.      CASH         CARD        KRAVEN
# 5      08-01-22 Mon         0.00      0.00     3,739.62         70.10
# 6      08-02-22 Tue         0.00      0.00     3,167.05        150.45
# 7      08-03-22 Wed         0.00      0.00     2,574.58        154.17
# 8      08-04-22 Thu         0.00      0.00     2,887.90         59.87
# 9      08-05-22 Fri         0.00      0.00     3,648.18        161.29
# 10     08-06-22 Sat         0.00      0.00     3,219.21        180.93
# ...

# %%
der.columns = ['DATE','A/R MISCE','PETTY CASH','CREDIT CARD','KRAVEN','CREW WAGES','REGISTER REPAIRS','FOOD EXPENSE','KITCHEN EQUIP',
              'MISC. EXPENSE','OFFICE EXPENSE','PAPER EXPENSE','PROMO EXPENSE','TRAVEL EXPENSE']
der
# Out:
#                DATE    A/R MISCE PETTY CASH  CREDIT CARD        KRAVEN  \
# 0   ===============  ===========   ========  ===========  ============
# 1   DANBRAD LIMITED          NaN        NaN          NaN           NaN
# 2   Store #52058 MA  RLBOROUGH S     TREET.  Information   from 08-01-
# 3               NaN          A/R      PETTY       CREDIT        KRAVEN
# 4              Date       MISCE.       CASH         CARD        KRAVEN
# 5      08-01-22 Mon         0.00       0.00     3,739.62         70.10
# 6      08-02-22 Tue         0.00       0.00     3,167.05        150.45
# 7      08-03-22 Wed         0.00       0.00     2,574.58        154.17
# 8      08-04-22 Thu         0.00       0.00     2,887.90         59.87
# 9      08-05-22 Fri         0.00       0.00     3,648.18        161.29
# 10     08-06-22 Sat         0.00       0.00     3,219.21        180.93
# 11     08-07-22 Sun         0.00       0.00     3,068.56          0.00
# ...

# %%
der = der.drop(axis=0, labels=0)
der = der.drop(axis=0, labels=1)
der = der.drop(axis=0, labels=2)
der = der.drop(axis=0, labels=3)
der = der.drop(axis=0, labels=4)

# %%
der
# Out:
#                DATE   A/R MISCE PETTY CASH  CREDIT CARD        KRAVEN  \
# 5      08-01-22 Mon        0.00       0.00     3,739.62         70.10
# 6      08-02-22 Tue        0.00       0.00     3,167.05        150.45
# 7      08-03-22 Wed        0.00       0.00     2,574.58        154.17
# 8      08-04-22 Thu        0.00       0.00     2,887.90         59.87
# 9      08-05-22 Fri        0.00       0.00     3,648.18        161.29
# 10     08-06-22 Sat        0.00       0.00     3,219.21        180.93
# 11     08-07-22 Sun        0.00       0.00     3,068.56          0.00
# 12  ---------------  -------- -   ------ -  --------- -  --------- --
# 13       Week Total        0.00       0.00    22,305.10        776.81
# 14     08-08-22 Mon        0.00       0.00     3,117.00          0.00
# 15     08-09-22 Tue        0.00       0.00    2,711.74c         89.65
# 16     08-10-22 Wed        0.00       0.00    3,085.12c         65.36
# ...

# %% [markdown]
# ### Save to csv

# %%
der.to_csv(f'{Restaurant}/{Report_Name}/{Restaurant}_{Report_Name}_{short_month}_{year}.pdf')

# %% [markdown]
# ### Non Product Inventory

# %%
Report_Name = "Non-ProductSales"

# %%
mnp = tabula.read_pdf(f'{Restaurant}/{Report_Name}/{Restaurant}_{Report_Name}_{short_month}_{year}.pdf', stream=True, guess=False, pandas_options={'header': None},
                     columns=(102.61, 195.85,286.76,376.67,466.29,558.38,654.10))[0]
mnp
# Out:
# 'pages' argument isn't specified.Will extract only from page 1 by default.
#                0              1         2                  3               4  \
# 0    DANBRAD LTD            NaN       NaN                NaN             NaN
# 1   rvenp_ventas  noproducto_en       NaN               MARL          BORUGH
# 2   201907241700            NaN       NaN           Non prod       uct sales
# 3            NaN            NaN       NaN  From : 08/01/2022  To: 08/31/2022
# 4            NaN            NaN       NaN                NaN             NaN
# 5            NaN            NaN       NaN                NaN             NaN
# 6            NaN   Happy meal t       oys         Celebratio              ns
# 7           Date       Quantity    Amount           Quantity          Amount
# 8     08/01/2022            156    193.44                  0               0
# 9     08/02/2022            119    147.56                  0               0
# ...

# %%
mnp.columns = ['DATE','QUANTITY','AMOUNT','QUANTITY','AMOUNT','QUANTITY','AMOUNT','TOTAL IMPORT']
mnp
# Out:
#             DATE       QUANTITY    AMOUNT           QUANTITY          AMOUNT  \
# 0    DANBRAD LTD            NaN       NaN                NaN             NaN
# 1   rvenp_ventas  noproducto_en       NaN               MARL          BORUGH
# 2   201907241700            NaN       NaN           Non prod       uct sales
# 3            NaN            NaN       NaN  From : 08/01/2022  To: 08/31/2022
# 4            NaN            NaN       NaN                NaN             NaN
# 5            NaN            NaN       NaN                NaN             NaN
# 6            NaN   Happy meal t       oys         Celebratio              ns
# 7           Date       Quantity    Amount           Quantity          Amount
# 8     08/01/2022            156    193.44                  0               0
# 9     08/02/2022            119    147.56                  0               0
# 10    08/03/2022             79     97.96                  0               0
# ...

# %%
mnp = mnp.drop(axis=0, labels=0)
mnp = mnp.drop(axis=0, labels=1)
mnp = mnp.drop(axis=0, labels=2)
mnp = mnp.drop(axis=0, labels=3)
mnp = mnp.drop(axis=0, labels=4)
mnp = mnp.drop(axis=0, labels=5)
mnp = mnp.drop(axis=0, labels=6)
mnp = mnp.drop(axis=0, labels=7)

# %%
mnp
# Out:
#           DATE QUANTITY    AMOUNT QUANTITY AMOUNT QUANTITY  AMOUNT  \
# 8   08/01/2022      156    193.44        0      0        3       6
# 9   08/02/2022      119    147.56        0      0        1       2
# 10  08/03/2022       79     97.96        0      0        0       0
# 11  08/04/2022      105     130.2        0      0        0       0
# 12  08/05/2022      127    157.48        0      0        2       4
# 13  08/06/2022      136    168.64        0      0        2       4
# 14  08/07/2022       91    112.84        0      0        3       6
# 15  08/08/2022      106    131.44        0      0        0       0
# 16  08/09/2022      101    125.24        0      0        0       0
# 17  08/10/2022      104    128.96        0      0        0       0
# 18  08/11/2022       77     95.48        0      0        0       0
# 19  08/12/2022      124    153.76        0      0        1       2
# 20  08/13/2022      130     161.2        0      0        0       0
# ...

# %% [markdown]
# ### Save to csv

# %%
mnp.to_csv(f'{Restaurant}/{Report_Name}/{Restaurant}_{Report_Name}_{short_month}_{year}.pdf')

# %% [markdown]
# ### Quality Cost

# %%
Report_Name = "QualityCost"

# %%
qc = tabula.read_pdf(f'{Restaurant}/{Report_Name}/{Restaurant}_{Report_Name}_{short_month}_{year}.pdf', stream=True, guess=False, pandas_options={'header': None},
                     columns=(147.39, 188.19,225.38,267.77,313.66,355.50,415.66,460.33,500.88))[0]
qc
# Out:
# 'pages' argument isn't specified.Will extract only from page 1 by default.
#                         0          1     2       3     4         5         6  \
# 0             DANBRAD LTD        NaN   NaN     NaN   NaN       NaN       NaN
# 1   rvenp_ventasnoproduct       o_en   NaN     NaN   NaN         M   ARLBORU
# 2            201907241700        NaN   NaN     NaN   NaN     Non p  roduct s
# 3                     NaN        NaN   NaN     NaN  From  : 08/01/  2022 To:
# 4                     NaN        NaN   NaN     NaN   NaN       NaN       NaN
# 5                     NaN        NaN   NaN     NaN   NaN       NaN       NaN
# 6                       H  appy meal  toys     NaN   NaN     Celeb   rations
# 7            Date Quantit          y   NaN  Amount   Qua     ntity         A
# 8          08/01/2022  15          6   NaN  193.44   NaN         0       NaN
# 9          08/02/2022  11          9   NaN  147.56   NaN         0       NaN
# ...

# %%
qc.columns = ['MENU ITEM','AVG. PRICE','FOOD COST%','UNITS SOLD','FOOD COST$','UNITS WASTED','MENU WST FOOD COST$','RECIPE COST: FOOD','RECIPE COST: PAPER', 'RECIPE COST: TOTAL']
qc
# Out:
#                 MENU ITEM AVG. PRICE FOOD COST% UNITS SOLD FOOD COST$  \
# 0             DANBRAD LTD        NaN        NaN        NaN        NaN
# 1   rvenp_ventasnoproduct       o_en        NaN        NaN        NaN
# 2            201907241700        NaN        NaN        NaN        NaN
# 3                     NaN        NaN        NaN        NaN       From
# 4                     NaN        NaN        NaN        NaN        NaN
# 5                     NaN        NaN        NaN        NaN        NaN
# 6                       H  appy meal       toys        NaN        NaN
# 7            Date Quantit          y        NaN     Amount        Qua
# 8          08/01/2022  15          6        NaN     193.44        NaN
# 9          08/02/2022  11          9        NaN     147.56        NaN
# 10          08/03/2022  7          9        NaN      97.96        NaN
# 11         08/04/2022  10          5        NaN      130.2        NaN
# ...

# %%
qc = qc.drop(axis=0, labels=0)
qc = qc.drop(axis=0, labels=1)
qc = qc.drop(axis=0, labels=2)
qc = qc.drop(axis=0, labels=3)
qc = qc.drop(axis=0, labels=4)
qc = qc.drop(axis=0, labels=5)
qc = qc.drop(axis=0, labels=6)
qc = qc.drop(axis=0, labels=7)

# %%
qc
# Out:
#          MENU ITEM AVG. PRICE FOOD COST% UNITS SOLD FOOD COST$ UNITS WASTED  \
# 8   08/01/2022  15          6        NaN     193.44        NaN            0
# 9   08/02/2022  11          9        NaN     147.56        NaN            0
# 10   08/03/2022  7          9        NaN      97.96        NaN            0
# 11  08/04/2022  10          5        NaN      130.2        NaN            0
# 12  08/05/2022  12          7        NaN     157.48        NaN            0
# 13  08/06/2022  13          6        NaN     168.64        NaN            0
# 14   08/07/2022  9          1        NaN     112.84        NaN            0
# 15  08/08/2022  10          6        NaN     131.44        NaN            0
# 16  08/09/2022  10          1        NaN     125.24        NaN            0
# 17  08/10/2022  10          4        NaN     128.96        NaN            0
# 18   08/11/2022  7          7        NaN      95.48        NaN            0
# ...

# %% [markdown]
# ### Save to csv

# %%
qc.to_csv(f'{Restaurant}/{Report_Name}/{Restaurant}_{Report_Name}_{short_month}_{year}.pdf')
